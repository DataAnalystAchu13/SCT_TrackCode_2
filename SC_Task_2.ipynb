# %%
import pandas as pd

# Read your diabetes dataset
df = pd.read_csv('/content/archive (2).zip')

# Check first few rows
df.head()
# Import important libraries for data analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Show plots inside the notebook
# %matplotlib inline
# Read the diabetes dataset
df = pd.read_csv('/content/archive (2).zip')
# Display first 5 rows
df.head()
# Check shape of dataset
print("Dataset shape:", df.shape)

# Check column names and data types
df.info()
# Check if there are missing values
df.isnull().sum()
# List of columns where 0 means missing
cols_with_zero_missing = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

# Replace 0 with NaN in these columns
df[cols_with_zero_missing] = df[cols_with_zero_missing].replace(0, np.nan)

# Check how many missing values are there now
df.isnull().sum()
# List of columns where 0 means missing
cols_with_zero_missing = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

# Replace 0 with NaN in these columns
df[cols_with_zero_missing] = df[cols_with_zero_missing].replace(0, np.nan)

# Check how many missing values are there now
df.isnull().sum()
# Fill missing BMI values with median
df['BMI'] = df['BMI'].fillna(df['BMI'].median())
# Check if any missing values remain
df.isnull().sum()
import numpy as np

cols_with_zero_missing = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

df[cols_with_zero_missing] = df[cols_with_zero_missing].replace(0, np.nan)
# Fill missing values with median for these columns
df[cols_with_zero_missing] = df[cols_with_zero_missing].fillna(df[cols_with_zero_missing].median())
df.isnull().sum()
# 1. Import libraries (already imported earlier, included for completeness)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 2. Display basic descriptive statistics
print("Basic Statistical Summary:")
print(df.describe())

# 3. Plot histograms for all columns to see their distribution
plt.figure(figsize=(15,10))

for i, column in enumerate(df.columns, 1):
    plt.subplot(3, 3, i)  # creates a grid of 3x3 plots
    df[column].hist(bins=20)
    plt.title(column)

plt.tight_layout()
plt.show()

# 4. Check counts of Outcome variable (target)
print("Outcome value counts:")
print(df['Outcome'].value_counts())

# 5. Plot Outcome distribution (bar chart)
sns.countplot(x='Outcome', data=df)
plt.title('Distribution of Diabetes Outcome')
plt.show()
# 1. Correlation matrix heatmap
corr = df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# 2. Pairplot for important variables
important_cols = ['Glucose', 'BMI', 'Age', 'Insulin', 'Outcome']
sns.pairplot(df[important_cols], hue='Outcome')
plt.show()

# 3. Boxplots for Glucose and BMI by Outcome
sns.boxplot(x='Outcome', y='Glucose', data=df)
plt.title('Glucose Levels by Diabetes Outcome')
plt.show()

sns.boxplot(x='Outcome', y='BMI', data=df)
plt.title('BMI Levels by Diabetes Outcome')
plt.show()
# Out:
# Dataset shape: (768, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# Basic Statistical Summary:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# ...
